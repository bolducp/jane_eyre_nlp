# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

with open('./jane_eyre.txt') as file:
    text = file.read()
    doc = nlp(text)

print(f"{'TOKEN':{10}} {'COARSE':{8}} {'FINE':{6}} {'DESCRIPTION'}")

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# TOKEN      COARSE   FINE   DESCRIPTION
# CHAPTER    NOUN     NN     noun, singular or mass
# I          PRON     PRP    pronoun, personal
#
#
#
#         SPACE    _SP    None
# There      ADV      EX     existential there
# was        VERB     VBD    verb, past tense
# no         DET      DT     determiner
# possibility NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# taking     VERB     VBG    verb, gerund or present participle
# a          DET      DT     determiner
# walk       NOUN     NN     noun, singular or mass
# that       DET      DT     determiner
# day        NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# We         PRON     PRP    pronoun, personal
# had        VERB     VBD    verb, past tense
# been       VERB     VBN    verb, past participle
#
#           SPACE           None
# wandering  VERB     VBG    verb, gerund or present participle
# ,          PUNCT    ,      punctuation mark, comma
# indeed     ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# leafless   NOUN     NN     noun, singular or mass
# shrubbery  NOUN     NN     noun, singular or mass
# an         DET      DT     determiner
# hour       NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# morning    NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# but        CCONJ    CC     conjunction, coordinating
#
#           SPACE           None
# since      ADP      IN     conjunction, subordinating or preposition
# dinner     NOUN     NN     noun, singular or mass
# (          PUNCT    -LRB-  left round bracket
# Mrs.       PROPN    NNP    noun, proper singular
# Reed       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# when       ADV      WRB    wh-adverb
# there      ADV      EX     existential there
# was        VERB     VBD    verb, past tense
# no         DET      DT     determiner
# company    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# dined      VERB     VBN    verb, past participle
# early      ADV      RB     adverb
# )          PUNCT    -RRB-  right round bracket
# the        DET      DT     determiner
# cold       ADJ      JJ     adjective
#
#           SPACE           None
# winter     NOUN     NN     noun, singular or mass
# wind       NOUN     NN     noun, singular or mass
# had        VERB     VBD    verb, past tense
# brought    VERB     VBN    verb, past participle
# with       ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# clouds     VERB     VBZ    verb, 3rd person singular present
# so         ADV      RB     adverb
# sombre     ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# a          DET      DT     determiner
# rain       NOUN     NN     noun, singular or mass
# so         ADV      RB     adverb
#
#           SPACE           None
# penetrating NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# that       ADP      IN     conjunction, subordinating or preposition
# further    ADV      RB     adverb
# out        ADJ      JJ     adjective
# -          PUNCT    HYPH   punctuation mark, hyphen
# door       NOUN     NN     noun, singular or mass
# exercise   NOUN     NN     noun, singular or mass
# was        VERB     VBD    verb, past tense
# now        ADV      RB     adverb
# out        ADP      IN     conjunction, subordinating or preposition
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# question   NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# I          PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# glad       ADJ      JJ     adjective
# of         ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# :          PUNCT    :      punctuation mark, colon or ellipsis
# I          PRON     PRP    pronoun, personal
# never      ADV      RB     adverb
# liked      VERB     VBD    verb, past tense
# long       ADJ      JJ     adjective
# walks      NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# especially ADV      RB     adverb
# on         ADP      IN     conjunction, subordinating or preposition
# chilly     ADJ      JJ     adjective
#
#           SPACE           None
# afternoons NOUN     NNS    noun, plural
# :          PUNCT    :      punctuation mark, colon or ellipsis
# dreadful   ADJ      JJ     adjective
# to         ADP      IN     conjunction, subordinating or preposition
# me         PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# the        DET      DT     determiner
# coming     VERB     VBG    verb, gerund or present participle
# home       ADV      RB     adverb
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# raw        ADJ      JJ     adjective
# twilight   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# with       ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# nipped     VERB     VBN    verb, past participle
# fingers    NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# toes       NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# a          DET      DT     determiner
# heart      NOUN     NN     noun, singular or mass
# saddened   VERB     VBN    verb, past participle
# by         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# chidings   NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# Bessie     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# the        DET      DT     determiner
# nurse      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# humbled    VERB     VBN    verb, past participle
# by         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# consciousness NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# my         ADJ      PRP$   pronoun, possessive
# physical   ADJ      JJ     adjective
# inferiority NOUN     NN     noun, singular or mass
# to         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# Eliza      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# John       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# Georgiana  PROPN    NNP    noun, proper singular
# Reed       PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# The        DET      DT     determiner
# said       VERB     VBD    verb, past tense
# Eliza      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# John       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# Georgiana  PROPN    NNP    noun, proper singular
# were       VERB     VBD    verb, past tense
# now        ADV      RB     adverb
# clustered  VERB     VBN    verb, past participle
# round      ADP      IN     conjunction, subordinating or preposition
# their      ADJ      PRP$   pronoun, possessive
# mama       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# drawing    NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# room       NOUN     NN     noun, singular or mass
# :          PUNCT    :      punctuation mark, colon or ellipsis
# she        PRON     PRP    pronoun, personal
# lay        VERB     VBD    verb, past tense
# reclined   VERB     VBN    verb, past participle
# on         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# sofa       NOUN     NN     noun, singular or mass
# by         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# fireside   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# with       ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# her        ADJ      PRP$   pronoun, possessive
# darlings   NOUN     NNS    noun, plural
# about      ADP      IN     conjunction, subordinating or preposition
# her        PRON     PRP    pronoun, personal
# (          PUNCT    -LRB-  left round bracket
# for        ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# time       NOUN     NN     noun, singular or mass
# neither    CCONJ    CC     conjunction, coordinating
# quarrelling VERB     VBG    verb, gerund or present participle
# nor        CCONJ    CC     conjunction, coordinating
# crying     VERB     VBG    verb, gerund or present participle
# )          PUNCT    -RRB-  right round bracket
#
#           SPACE           None
# looked     VERB     VBD    verb, past tense
# perfectly  ADV      RB     adverb
# happy      ADJ      JJ     adjective
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Me         PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# she        PRON     PRP    pronoun, personal
# had        VERB     VBD    verb, past tense
# dispensed  VERB     VBN    verb, past participle
# from       ADP      IN     conjunction, subordinating or preposition
# joining    VERB     VBG    verb, gerund or present participle
# the        DET      DT     determiner
# group      NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
#
#           SPACE           None
# saying     VERB     VBG    verb, gerund or present participle
# ,          PUNCT    ,      punctuation mark, comma
# "          PUNCT    ``     opening quotation mark
# She        PRON     PRP    pronoun, personal
# regretted  VERB     VBD    verb, past tense
# to         PART     TO     infinitival to
# be         VERB     VB     verb, base form
# under      ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# necessity  NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# keeping    VERB     VBG    verb, gerund or present participle
# me         PRON     PRP    pronoun, personal
# at         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
#
#           SPACE           None
# distance   NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# but        CCONJ    CC     conjunction, coordinating
# that       ADP      IN     conjunction, subordinating or preposition
# until      ADP      IN     conjunction, subordinating or preposition
# she        PRON     PRP    pronoun, personal
# heard      VERB     VBD    verb, past tense
# from       ADP      IN     conjunction, subordinating or preposition
# Bessie     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# could      VERB     MD     verb, modal auxiliary
# discover   VERB     VB     verb, base form
# by         ADP      IN     conjunction, subordinating or preposition
# her        ADJ      PRP$   pronoun, possessive
#
#           SPACE           None
# own        ADJ      JJ     adjective
# observation NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# that       ADP      IN     conjunction, subordinating or preposition
# I          PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# endeavouring VERB     VBG    verb, gerund or present participle
# in         ADP      IN     conjunction, subordinating or preposition
# good       ADJ      JJ     adjective
# earnest    NOUN     NN     noun, singular or mass
# to         PART     TO     infinitival to
# acquire    VERB     VB     verb, base form
# a          DET      DT     determiner
#
#           SPACE           None
# more       ADV      RBR    adverb, comparative
# sociable   ADJ      JJ     adjective
# and        CCONJ    CC     conjunction, coordinating
# childlike  ADJ      JJ     adjective
# disposition NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# a          DET      DT     determiner
# more       ADV      RBR    adverb, comparative
# attractive ADJ      JJ     adjective
# and        CCONJ    CC     conjunction, coordinating
# sprightly  ADJ      JJ     adjective
#
#           SPACE           None
# manner     NOUN     NN     noun, singular or mass
# --         PUNCT    :      punctuation mark, colon or ellipsis
# something  NOUN     NN     noun, singular or mass
# lighter    ADJ      JJR    adjective, comparative
# ,          PUNCT    ,      punctuation mark, comma
# franker    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# more       ADV      RBR    adverb, comparative
# natural    ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# as         ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# were       VERB     VBD    verb, past tense
# --         PUNCT    :      punctuation mark, colon or ellipsis
# she        PRON     PRP    pronoun, personal
# really     ADV      RB     adverb
#
#           SPACE           None
# must       VERB     MD     verb, modal auxiliary
# exclude    VERB     VB     verb, base form
# me         PRON     PRP    pronoun, personal
# from       ADP      IN     conjunction, subordinating or preposition
# privileges NOUN     NNS    noun, plural
# intended   VERB     VBN    verb, past participle
# only       ADV      RB     adverb
# for        ADP      IN     conjunction, subordinating or preposition
# contented  ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# happy      ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# little     ADJ      JJ     adjective
# children   NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# What       NOUN     WP     wh-pronoun, personal
# does       VERB     VBZ    verb, 3rd person singular present
# Bessie     PROPN    NNP    noun, proper singular
# say        VERB     VB     verb, base form
# I          PRON     PRP    pronoun, personal
# have       VERB     VBP    verb, non-3rd person singular present
# done       VERB     VBN    verb, past participle
# ?          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
# I          PRON     PRP    pronoun, personal
# asked      VERB     VBD    verb, past tense
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# "          PUNCT    ``     opening quotation mark
# Jane       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# do         VERB     VBP    verb, non-3rd person singular present
# n't        ADV      RB     adverb
# like       VERB     VB     verb, base form
# cavillers  NOUN     NNS    noun, plural
# or         CCONJ    CC     conjunction, coordinating
# questioners NOUN     NNS    noun, plural
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# besides    ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# there      ADV      EX     existential there
# is         VERB     VBZ    verb, 3rd person singular present
# something  NOUN     NN     noun, singular or mass
#
#           SPACE           None
# truly      ADV      RB     adverb
# forbidding VERB     VBG    verb, gerund or present participle
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# child      NOUN     NN     noun, singular or mass
# taking     VERB     VBG    verb, gerund or present participle
# up         PART     RP     adverb, particle
# her        ADJ      PRP$   pronoun, possessive
# elders     NOUN     NNS    noun, plural
# in         ADP      IN     conjunction, subordinating or preposition
# that       DET      DT     determiner
# manner     NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Be         PROPN    NNP    noun, proper singular
#
#           SPACE           None
# seated     VERB     VBN    verb, past participle
# somewhere  ADV      RB     adverb
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# until      ADP      IN     conjunction, subordinating or preposition
# you        PRON     PRP    pronoun, personal
# can        VERB     MD     verb, modal auxiliary
# speak      VERB     VB     verb, base form
# pleasantly ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# remain     VERB     VBP    verb, non-3rd person singular present
# silent     ADJ      JJ     adjective
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# A          DET      DT     determiner
# breakfast  NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# room       NOUN     NN     noun, singular or mass
# adjoined   VERB     VBD    verb, past tense
# the        DET      DT     determiner
# drawing    NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# room       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# slipped    VERB     VBD    verb, past tense
# in         ADV      RB     adverb
# there      ADV      RB     adverb
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# It         PRON     PRP    pronoun, personal
#
#           SPACE           None
# contained  VERB     VBD    verb, past tense
# a          DET      DT     determiner
# bookcase   NOUN     NN     noun, singular or mass
# :          PUNCT    :      punctuation mark, colon or ellipsis
# I          PRON     PRP    pronoun, personal
# soon       ADV      RB     adverb
# possessed  VERB     VBD    verb, past tense
# myself     PRON     PRP    pronoun, personal
# of         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# volume     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# taking     VERB     VBG    verb, gerund or present participle
# care       NOUN     NN     noun, singular or mass
#
#           SPACE           None
# that       ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# should     VERB     MD     verb, modal auxiliary
# be         VERB     VB     verb, base form
# one        NUM      CD     cardinal number
# stored     VERB     VBN    verb, past participle
# with       ADP      IN     conjunction, subordinating or preposition
# pictures   NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# I          PRON     PRP    pronoun, personal
# mounted    VERB     VBD    verb, past tense
# into       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# window-    PROPN    NNP    noun, proper singular
#
#           SPACE           None
# seat       NOUN     NN     noun, singular or mass
# :          PUNCT    :      punctuation mark, colon or ellipsis
# gathering  VERB     VBG    verb, gerund or present participle
# up         PART     RP     adverb, particle
# my         ADJ      PRP$   pronoun, possessive
# feet       NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# sat        VERB     VBD    verb, past tense
# cross      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# legged     ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# like       ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# Turk       PROPN    NNP    noun, proper singular
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# ,          PUNCT    ,      punctuation mark, comma
# having     VERB     VBG    verb, gerund or present participle
#
#           SPACE           None
# drawn      VERB     VBN    verb, past participle
# the        DET      DT     determiner
# red        ADJ      JJ     adjective
# moreen     NOUN     NN     noun, singular or mass
# curtain    NOUN     NN     noun, singular or mass
# nearly     ADV      RB     adverb
# close      ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# shrined    VERB     VBN    verb, past participle
# in         ADP      IN     conjunction, subordinating or preposition
# double     ADJ      JJ     adjective
#
#           SPACE           None
# retirement NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# Folds      NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# scarlet    ADJ      JJ     adjective
# drapery    NOUN     NN     noun, singular or mass
# shut       VERB     VBN    verb, past participle
# in         ADP      IN     conjunction, subordinating or preposition
# my         ADJ      PRP$   pronoun, possessive
# view       NOUN     NN     noun, singular or mass
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# right      ADJ      JJ     adjective
# hand       NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# left       ADJ      JJ     adjective
#
#           SPACE           None
# were       VERB     VBD    verb, past tense
# the        DET      DT     determiner
# clear      ADJ      JJ     adjective
# panes      NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# glass      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# protecting VERB     VBG    verb, gerund or present participle
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# not        ADV      RB     adverb
# separating VERB     VBG    verb, gerund or present participle
# me         PRON     PRP    pronoun, personal
# from       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
#
#           SPACE           None
# drear      NOUN     NN     noun, singular or mass
# November   PROPN    NNP    noun, proper singular
# day        NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# At         ADP      IN     conjunction, subordinating or preposition
# intervals  NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# while      ADP      IN     conjunction, subordinating or preposition
# turning    VERB     VBG    verb, gerund or present participle
# over       PART     RP     adverb, particle
# the        DET      DT     determiner
# leaves     NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# my         ADJ      PRP$   pronoun, possessive
#
#           SPACE           None
# book       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# studied    VERB     VBD    verb, past tense
# the        DET      DT     determiner
# aspect     NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# that       DET      DT     determiner
# winter     NOUN     NN     noun, singular or mass
# afternoon  NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Afar       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# it         PRON     PRP    pronoun, personal
# offered    VERB     VBD    verb, past tense
# a          DET      DT     determiner
#
#           SPACE           None
# pale       ADJ      JJ     adjective
# blank      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# mist       NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# cloud      NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# near       ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# scene      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# wet        ADJ      JJ     adjective
# lawn       NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# storm      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# beat       VERB     VBN    verb, past participle
#
#           SPACE           None
# shrub      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# with       ADP      IN     conjunction, subordinating or preposition
# ceaseless  NOUN     NN     noun, singular or mass
# rain       NOUN     NN     noun, singular or mass
# sweeping   VERB     VBG    verb, gerund or present participle
# away       ADV      RB     adverb
# wildly     ADV      RB     adverb
# before     ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# long       ADJ      JJ     adjective
# and        CCONJ    CC     conjunction, coordinating
#
#           SPACE           None
# lamentable ADJ      JJ     adjective
# blast      NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# I          PRON     PRP    pronoun, personal
# returned   VERB     VBD    verb, past tense
# to         ADP      IN     conjunction, subordinating or preposition
# my         ADJ      PRP$   pronoun, possessive
# book       NOUN     NN     noun, singular or mass
# --         PUNCT    :      punctuation mark, colon or ellipsis
# Bewick     PROPN    NNP    noun, proper singular
# 's         PART     POS    possessive ending
# History    NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# British    ADJ      JJ     adjective
# Birds      PROPN    NNPS   noun, proper plural
# :          PUNCT    :      punctuation mark, colon or ellipsis
# the        DET      DT     determiner
# letterpress ADJ      JJ     adjective
#
#           SPACE           None
# thereof    ADV      RB     adverb
# I          PRON     PRP    pronoun, personal
# cared      VERB     VBD    verb, past tense
# little     ADJ      JJ     adjective
# for        ADP      IN     conjunction, subordinating or preposition
# ,          PUNCT    ,      punctuation mark, comma
# generally  ADV      RB     adverb
# speaking   VERB     VBG    verb, gerund or present participle
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# yet        ADV      RB     adverb
# there      ADV      EX     existential there
# were       VERB     VBD    verb, past tense
#
#           SPACE           None
# certain    ADJ      JJ     adjective
# introductory ADJ      JJ     adjective
# pages      NOUN     NNS    noun, plural
# that       ADJ      WDT    wh-determiner
# ,          PUNCT    ,      punctuation mark, comma
# child      NOUN     NN     noun, singular or mass
# as         ADP      IN     conjunction, subordinating or preposition
# I          PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# could      VERB     MD     verb, modal auxiliary
# not        ADV      RB     adverb
# pass       VERB     VB     verb, base form
# quite      ADV      RB     adverb
#
#           SPACE           None
# as         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# blank      NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# They       PRON     PRP    pronoun, personal
# were       VERB     VBD    verb, past tense
# those      DET      DT     determiner
# which      ADJ      WDT    wh-determiner
# treat      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# haunts     NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# sea        NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# fowl       NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# of         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# "          PUNCT    ''     closing quotation mark
# the        DET      DT     determiner
# solitary   ADJ      JJ     adjective
# rocks      NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# promontories NOUN     NNS    noun, plural
# "          PUNCT    ''     closing quotation mark
# by         ADP      IN     conjunction, subordinating or preposition
# them       PRON     PRP    pronoun, personal
# only       ADV      RB     adverb
# inhabited  VERB     VBD    verb, past tense
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
#
#           SPACE           None
# coast      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# Norway     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# studded    VERB     VBD    verb, past tense
# with       ADP      IN     conjunction, subordinating or preposition
# isles      NOUN     NNS    noun, plural
# from       ADP      IN     conjunction, subordinating or preposition
# its        ADJ      PRP$   pronoun, possessive
# southern   ADJ      JJ     adjective
# extremity  NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
#
#           SPACE           None
# Lindeness  PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# or         CCONJ    CC     conjunction, coordinating
# Naze       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# North      PROPN    NNP    noun, proper singular
# Cape--     PROPN    NNP    noun, proper singular
#
#
#          SPACE    _SP    None
# "          PUNCT    ``     opening quotation mark
# Where      ADV      WRB    wh-adverb
# the        DET      DT     determiner
# Northern   PROPN    NNP    noun, proper singular
# Ocean      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# in         ADP      IN     conjunction, subordinating or preposition
# vast       ADJ      JJ     adjective
# whirls     NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE    _SP    None
# Boils      PROPN    NNPS   noun, proper plural
# round      VERB     VB     verb, base form
# the        DET      DT     determiner
# naked      ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# melancholy ADJ      JJ     adjective
# isles      NOUN     NNS    noun, plural
#
#           SPACE    _SP    None
# Of         ADP      IN     conjunction, subordinating or preposition
# farthest   ADJ      JJS    adjective, superlative
# Thule      PROPN    NNP    noun, proper singular
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# Atlantic   PROPN    NNP    noun, proper singular
# surge      NOUN     NN     noun, singular or mass
#
#           SPACE    _SP    None
# Pours      PROPN    NNP    noun, proper singular
# in         PART     RP     adverb, particle
# among      ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# stormy     ADJ      JJ     adjective
# Hebrides   PROPN    NNPS   noun, proper plural
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#
#          SPACE    _SP    None
# Nor        CCONJ    CC     conjunction, coordinating
# could      VERB     MD     verb, modal auxiliary
# I          PRON     PRP    pronoun, personal
# pass       VERB     VB     verb, base form
# unnoticed  ADJ      JJ     adjective
# the        DET      DT     determiner
# suggestion NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# bleak      ADJ      JJ     adjective
# shores     NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# Lapland    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# Siberia    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# Spitzbergen PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# Nova       PROPN    NNP    noun, proper singular
# Zembla     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# Iceland    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# Greenland  PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# with       ADP      IN     conjunction, subordinating or preposition
# "          PUNCT    ``     opening quotation mark
# the        DET      DT     determiner
# vast       ADJ      JJ     adjective
#
#           SPACE           None
# sweep      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# Arctic     PROPN    NNP    noun, proper singular
# Zone       PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# those      DET      DT     determiner
# forlorn    ADJ      JJ     adjective
# regions    NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# dreary     ADJ      JJ     adjective
# space      NOUN     NN     noun, singular or mass
# ,--        PUNCT    ,      punctuation mark, comma
# that       ADJ      WDT    wh-determiner
#
#           SPACE           None
# reservoir  NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# frost      NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# snow       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# where      ADV      WRB    wh-adverb
# firm       ADJ      JJ     adjective
# fields     NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# ice        NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# the        DET      DT     determiner
# accumulation NOUN     NN     noun, singular or mass
#
#           SPACE           None
# of         ADP      IN     conjunction, subordinating or preposition
# centuries  NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# winters    NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# glazed     VERB     VBN    verb, past participle
# in         ADP      IN     conjunction, subordinating or preposition
# Alpine     PROPN    NNP    noun, proper singular
# heights    NOUN     NNS    noun, plural
# above      ADP      IN     conjunction, subordinating or preposition
# heights    NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# surround   VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# the        DET      DT     determiner
# pole       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# concentre  VERB     VB     verb, base form
# the        DET      DT     determiner
# multiplied ADJ      JJ     adjective
# rigours    NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# extreme    ADJ      JJ     adjective
# cold       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#            SPACE           None
# Of         PROPN    NNP    noun, proper singular
#
#           SPACE           None
# these      DET      DT     determiner
# death      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# white      ADJ      JJ     adjective
# realms     NOUN     NNS    noun, plural
# I          PRON     PRP    pronoun, personal
# formed     VERB     VBD    verb, past tense
# an         DET      DT     determiner
# idea       NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# my         ADJ      PRP$   pronoun, possessive
# own        ADJ      JJ     adjective
# :          PUNCT    :      punctuation mark, colon or ellipsis
# shadowy    ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# like       ADP      IN     conjunction, subordinating or preposition
# all        DET      DT     determiner
#
#           SPACE           None
# the        DET      DT     determiner
# half       ADV      RB     adverb
# -          PUNCT    HYPH   punctuation mark, hyphen
# comprehended VERB     VBN    verb, past participle
# notions    NOUN     NNS    noun, plural
# that       ADJ      WDT    wh-determiner
# float      VERB     VBP    verb, non-3rd person singular present
# dim        NOUN     NN     noun, singular or mass
# through    ADP      IN     conjunction, subordinating or preposition
# children   NOUN     NNS    noun, plural
# 's         PART     POS    possessive ending
# brains     NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# but        CCONJ    CC     conjunction, coordinating
# strangely  ADV      RB     adverb
# impressive ADJ      JJ     adjective
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# The        DET      DT     determiner
# words      NOUN     NNS    noun, plural
# in         ADP      IN     conjunction, subordinating or preposition
# these      DET      DT     determiner
# introductory ADJ      JJ     adjective
# pages      NOUN     NNS    noun, plural
#
#           SPACE           None
# connected  VERB     VBD    verb, past tense
# themselves PRON     PRP    pronoun, personal
# with       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# succeeding VERB     VBG    verb, gerund or present participle
# vignettes  NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# gave       VERB     VBD    verb, past tense
# significance NOUN     NN     noun, singular or mass
#
#           SPACE           None
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# rock       NOUN     NN     noun, singular or mass
# standing   VERB     VBG    verb, gerund or present participle
# up         PART     RP     adverb, particle
# alone      ADV      RB     adverb
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# sea        NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# billow     NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# spray      VERB     VBP    verb, non-3rd person singular present
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# broken     VERB     VBN    verb, past participle
#
#           SPACE           None
# boat       NOUN     NN     noun, singular or mass
# stranded   VERB     VBN    verb, past participle
# on         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# desolate   ADJ      JJ     adjective
# coast      NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# cold       ADJ      JJ     adjective
# and        CCONJ    CC     conjunction, coordinating
# ghastly    ADV      RB     adverb
# moon       NOUN     NN     noun, singular or mass
# glancing   VERB     VBG    verb, gerund or present participle
#
#           SPACE           None
# through    ADP      IN     conjunction, subordinating or preposition
# bars       NOUN     NNS    noun, plural
# of         ADP      IN     conjunction, subordinating or preposition
# cloud      NOUN     NN     noun, singular or mass
# at         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# wreck      NOUN     NN     noun, singular or mass
# just       ADV      RB     adverb
# sinking    VERB     VBG    verb, gerund or present participle
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# I          PRON     PRP    pronoun, personal
# can        VERB     MD     verb, modal auxiliary
# not        ADV      RB     adverb
# tell       VERB     VB     verb, base form
# what       NOUN     WP     wh-pronoun, personal
# sentiment  NOUN     NN     noun, singular or mass
# haunted    VERB     VBD    verb, past tense
# the        DET      DT     determiner
# quite      ADV      RB     adverb
# solitary   ADJ      JJ     adjective
# churchyard NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# with       ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# its        ADJ      PRP$   pronoun, possessive
# inscribed  ADJ      JJ     adjective
# headstone  NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# its        ADJ      PRP$   pronoun, possessive
# gate       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# its        ADJ      PRP$   pronoun, possessive
# two        NUM      CD     cardinal number
# trees      NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# its        ADJ      PRP$   pronoun, possessive
# low        ADJ      JJ     adjective
# horizon    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# girdled    VERB     VBN    verb, past participle
# by         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# broken     ADJ      JJ     adjective
# wall       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# its        ADJ      PRP$   pronoun, possessive
# newly      ADV      RB     adverb
# -          PUNCT    HYPH   punctuation mark, hyphen
# risen      VERB     VBN    verb, past participle
# crescent   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# attesting  VERB     VBG    verb, gerund or present participle
# the        DET      DT     determiner
#
#           SPACE           None
# hour       NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# eventide   NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# The        DET      DT     determiner
# two        NUM      CD     cardinal number
# ships      NOUN     NNS    noun, plural
# becalmed   VERB     VBN    verb, past participle
# on         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# torpid     ADJ      JJ     adjective
# sea        NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# believed   VERB     VBD    verb, past tense
# to         PART     TO     infinitival to
# be         VERB     VB     verb, base form
# marine     ADJ      JJ     adjective
# phantoms   NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# The        DET      DT     determiner
# fiend      NOUN     NN     noun, singular or mass
# pinning    VERB     VBG    verb, gerund or present participle
# down       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# thief      NOUN     NN     noun, singular or mass
# 's         PART     POS    possessive ending
# pack       NOUN     NN     noun, singular or mass
# behind     ADP      IN     conjunction, subordinating or preposition
# him        PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# passed     VERB     VBD    verb, past tense
# over       PART     RP     adverb, particle
#
#           SPACE           None
# quickly    ADV      RB     adverb
# :          PUNCT    :      punctuation mark, colon or ellipsis
# it         PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# an         DET      DT     determiner
# object     NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# terror     NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# So         ADV      RB     adverb
# was        VERB     VBD    verb, past tense
# the        DET      DT     determiner
# black      ADJ      JJ     adjective
# horned     VERB     VBN    verb, past participle
# thing      NOUN     NN     noun, singular or mass
# seated     VERB     VBN    verb, past participle
# aloof      NOUN     NN     noun, singular or mass
# on         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# ...
# that       DET      DT     determiner
# room       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# was        VERB     VBD    verb, past tense
# laid       VERB     VBN    verb, past participle
# out        PART     RP     adverb, particle
# there      ADV      RB     adverb
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE           None
# Neither    CCONJ    CC     conjunction, coordinating
# Bessie     PROPN    NNP    noun, proper singular
# nor        CCONJ    CC     conjunction, coordinating
# any        DET      DT     determiner
# one        NOUN     NN     noun, singular or mass
# else       ADV      RB     adverb
# will       VERB     MD     verb, modal auxiliary
# go         VERB     VB     verb, base form
# into       ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# at         ADP      IN     conjunction, subordinating or preposition
# night      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# if         ADP      IN     conjunction, subordinating or preposition
# they       PRON     PRP    pronoun, personal
# can        VERB     MD     verb, modal auxiliary
#
#           SPACE           None
# help       VERB     VB     verb, base form
# it         PRON     PRP    pronoun, personal
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# it         PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
# cruel      ADJ      JJ     adjective
# to         PART     TO     infinitival to
# shut       VERB     VB     verb, base form
# me         PRON     PRP    pronoun, personal
# up         PART     RP     adverb, particle
# alone      ADV      RB     adverb
# without    ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# candle     NOUN     NN     noun, singular or mass
# ,--        PUNCT    ,      punctuation mark, comma
# so         ADV      RB     adverb
# cruel      ADJ      JJ     adjective
#
#           SPACE           None
# that       ADJ      WDT    wh-determiner
# I          PRON     PRP    pronoun, personal
# think      VERB     VBP    verb, non-3rd person singular present
# I          PRON     PRP    pronoun, personal
# shall      VERB     MD     verb, modal auxiliary
# never      ADV      RB     adverb
# forget     VERB     VB     verb, base form
# it         PRON     PRP    pronoun, personal
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# Nonsense   NOUN     NN     noun, singular or mass
# !          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# And        CCONJ    CC     conjunction, coordinating
# is         VERB     VBZ    verb, 3rd person singular present
# it         PRON     PRP    pronoun, personal
# that       ADJ      WDT    wh-determiner
# makes      VERB     VBZ    verb, 3rd person singular present
# you        PRON     PRP    pronoun, personal
# so         ADV      RB     adverb
# miserable  ADJ      JJ     adjective
# ?          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Are        VERB     VBP    verb, non-3rd person singular present
# you        PRON     PRP    pronoun, personal
# afraid     ADJ      JJ     adjective
# now        ADV      RB     adverb
# in         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# daylight   NOUN     NN     noun, singular or mass
# ?          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# No         INTJ     UH     interjection
# :          PUNCT    :      punctuation mark, colon or ellipsis
# but        CCONJ    CC     conjunction, coordinating
# night      NOUN     NN     noun, singular or mass
# will       VERB     MD     verb, modal auxiliary
# come       VERB     VB     verb, base form
# again      ADV      RB     adverb
# before     ADP      IN     conjunction, subordinating or preposition
# long       ADV      RB     adverb
# :          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# besides    ADV      RB     adverb
# ,--        PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# am         VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# unhappy    ADJ      JJ     adjective
# ,--        PUNCT    ,      punctuation mark, comma
# very       ADV      RB     adverb
# unhappy    ADJ      JJ     adjective
# ,          PUNCT    ,      punctuation mark, comma
# for        ADP      IN     conjunction, subordinating or preposition
# other      ADJ      JJ     adjective
# things     NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# What       NOUN     WP     wh-pronoun, personal
# other      ADJ      JJ     adjective
# things     NOUN     NNS    noun, plural
# ?          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Can        VERB     MD     verb, modal auxiliary
# you        PRON     PRP    pronoun, personal
# tell       VERB     VB     verb, base form
# me         PRON     PRP    pronoun, personal
# some       DET      DT     determiner
# of         ADP      IN     conjunction, subordinating or preposition
# them       PRON     PRP    pronoun, personal
# ?          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#
#          SPACE    _SP    None
# How        ADV      WRB    wh-adverb
# much       ADJ      JJ     adjective
# I          PRON     PRP    pronoun, personal
# wished     VERB     VBD    verb, past tense
# to         PART     TO     infinitival to
# reply      VERB     VB     verb, base form
# fully      ADV      RB     adverb
# to         ADP      IN     conjunction, subordinating or preposition
# this       DET      DT     determiner
# question   NOUN     NN     noun, singular or mass
# !          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# How        ADV      WRB    wh-adverb
# difficult  ADJ      JJ     adjective
# it         PRON     PRP    pronoun, personal
# was        VERB     VBD    verb, past tense
#
#           SPACE           None
# to         PART     TO     infinitival to
# frame      VERB     VB     verb, base form
# any        DET      DT     determiner
# answer     NOUN     NN     noun, singular or mass
# !          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Children   PROPN    NNP    noun, proper singular
# can        VERB     MD     verb, modal auxiliary
# feel       VERB     VB     verb, base form
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# they       PRON     PRP    pronoun, personal
# can        VERB     MD     verb, modal auxiliary
# not        ADV      RB     adverb
# analyse    VERB     VB     verb, base form
# their      ADJ      PRP$   pronoun, possessive
#
#           SPACE           None
# feelings   NOUN     NNS    noun, plural
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# if         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# analysis   NOUN     NN     noun, singular or mass
# is         VERB     VBZ    verb, 3rd person singular present
# partially  ADV      RB     adverb
# effected   VERB     VBN    verb, past participle
# in         ADP      IN     conjunction, subordinating or preposition
# thought    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# they       PRON     PRP    pronoun, personal
# know       VERB     VBP    verb, non-3rd person singular present
#
#           SPACE           None
# not        ADV      RB     adverb
# how        ADV      WRB    wh-adverb
# to         PART     TO     infinitival to
# express    VERB     VB     verb, base form
# the        DET      DT     determiner
# result     NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# process    NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# words      NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# Fearful    PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# however    ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# of         ADP      IN     conjunction, subordinating or preposition
# losing     VERB     VBG    verb, gerund or present participle
# this       DET      DT     determiner
# first      ADJ      JJ     adjective
# and        CCONJ    CC     conjunction, coordinating
# only       ADJ      JJ     adjective
# opportunity NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# relieving  VERB     VBG    verb, gerund or present participle
# my         ADJ      PRP$   pronoun, possessive
# grief      NOUN     NN     noun, singular or mass
# by         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE           None
# imparting  VERB     VBG    verb, gerund or present participle
# it         PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# ,          PUNCT    ,      punctuation mark, comma
# after      ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# disturbed  ADJ      JJ     adjective
# pause      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# contrived  VERB     VBD    verb, past tense
# to         PART     TO     infinitival to
# frame      VERB     VB     verb, base form
# a          DET      DT     determiner
# meagre     NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE           None
# though     ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# as         ADV      RB     adverb
# far        ADV      RB     adverb
# as         ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# went       VERB     VBD    verb, past tense
# ,          PUNCT    ,      punctuation mark, comma
# true       ADJ      JJ     adjective
# response   NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# "          PUNCT    ``     opening quotation mark
# For        ADP      IN     conjunction, subordinating or preposition
# one        NUM      CD     cardinal number
# thing      NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# I          PRON     PRP    pronoun, personal
# have       VERB     VBP    verb, non-3rd person singular present
# no         DET      DT     determiner
# father     NOUN     NN     noun, singular or mass
# or         CCONJ    CC     conjunction, coordinating
# mother     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# brothers   NOUN     NNS    noun, plural
# or         CCONJ    CC     conjunction, coordinating
# sisters    NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ``     opening quotation mark
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# You        PRON     PRP    pronoun, personal
# have       VERB     VBP    verb, non-3rd person singular present
# a          DET      DT     determiner
# kind       NOUN     NN     noun, singular or mass
# aunt       NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# cousins    NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#
#          SPACE    _SP    None
# Again      ADV      RB     adverb
# I          PRON     PRP    pronoun, personal
# paused     VERB     VBD    verb, past tense
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# then       ADV      RB     adverb
# bunglingly ADV      RB     adverb
# enounced-- PROPN    NNP    noun, proper singular
#
#
#          SPACE    _SP    None
# "          PUNCT    ''     closing quotation mark
# But        CCONJ    CC     conjunction, coordinating
# John       PROPN    NNP    noun, proper singular
# Reed       PROPN    NNP    noun, proper singular
# knocked    VERB     VBD    verb, past tense
# me         PRON     PRP    pronoun, personal
# down       PART     RP     adverb, particle
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# my         ADJ      PRP$   pronoun, possessive
# aunt       NOUN     NN     noun, singular or mass
# shut       VERB     VBD    verb, past tense
# me         PRON     PRP    pronoun, personal
# up         PART     RP     adverb, particle
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# red        ADJ      JJ     adjective
# -          PUNCT    HYPH   punctuation mark, hyphen
# room       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#
#          SPACE    _SP    None
# Mr.        PROPN    NNP    noun, proper singular
# Lloyd      PROPN    NNP    noun, proper singular
# a          DET      DT     determiner
# second     ADJ      JJ     adjective
# time       NOUN     NN     noun, singular or mass
# produced   VERB     VBD    verb, past tense
# his        ADJ      PRP$   pronoun, possessive
# snuff      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# box        NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# "          PUNCT    ``     opening quotation mark
# Do         VERB     VBP    verb, non-3rd person singular present
# n't        ADV      RB     adverb
# you        PRON     PRP    pronoun, personal
# think      VERB     VB     verb, base form
# Gateshead  PROPN    NNP    noun, proper singular
# Hall       PROPN    NNP    noun, proper singular
# a          DET      DT     determiner
# very       ADV      RB     adverb
# beautiful  ADJ      JJ     adjective
# house      NOUN     NN     noun, singular or mass
# ?          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
# asked      VERB     VBD    verb, past tense
# he         PRON     PRP    pronoun, personal
# .          PUNCT    .      punctuation mark, sentence closer
#            SPACE           None
# "          PUNCT    ``     opening quotation mark
# Are        PROPN    NNP    noun, proper singular
#
#           SPACE           None
# you        PRON     PRP    pronoun, personal
# not        ADV      RB     adverb
# very       ADV      RB     adverb
# thankful   ADJ      JJ     adjective
# to         PART     TO     infinitival to
# have       VERB     VB     verb, base form
# such       ADJ      PDT    predeterminer
# a          DET      DT     determiner
# fine       ADJ      JJ     adjective
# place      NOUN     NN     noun, singular or mass
# to         PART     TO     infinitival to
# live       VERB     VB     verb, base form
# at         ADP      IN     conjunction, subordinating or preposition
# ?          PUNCT    .      punctuation mark, sentence closer
# "          PUNCT    ''     closing quotation mark
#
#
#          SPACE    _SP    None

# %%
POS_counts = doc.count_by(spacy.attrs.POS)

for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 83. ADJ  : 774
# 84. ADP  : 848
# 85. ADV  : 528
# 88. CCONJ: 332
# 89. DET  : 648
# 90. INTJ : 18
# 91. NOUN : 1325
# 92. NUM  : 35
# 93. PART : 182
# 94. PRON : 682
# 95. PROPN: 301
# 96. PUNCT: 1449
# 99. VERB : 1419
# 100. X    : 3
# 102. SPACE: 767

# %%
percent = 100*POS_counts[91]/len(doc)

print(f'{POS_counts[91]}/{len(doc)} = {percent:{.4}}%')
# Out:
# 1325/9311 = 14.23%

# %%
displacy.render(list(doc.sents)[2], style='dep', jupyter=True, options={'distance': 110})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="948-0" class="displacy" width="1260" height="302.0" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">There</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">possibility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">taking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">walk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">day.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-0" stroke-width="2px" d="M70,167.0 C70,112.0 150.0,112.0 150.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">expl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L62,157.0 78,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-1" stroke-width="2px" d="M290,167.0 C290,112.0 370.0,112.0 370.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,169.0 L282,157.0 298,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-2" stroke-width="2px" d="M180,167.0 C180,57.0 375.0,57.0 375.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M375.0,169.0 L383.0,157.0 367.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-3" stroke-width="2px" d="M400,167.0 C400,112.0 480.0,112.0 480.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,169.0 L488.0,157.0 472.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-4" stroke-width="2px" d="M510,167.0 C510,112.0 590.0,112.0 590.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M590.0,169.0 L598.0,157.0 582.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-5" stroke-width="2px" d="M730,167.0 C730,112.0 810.0,112.0 810.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,169.0 L722,157.0 738,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-6" stroke-width="2px" d="M620,167.0 C620,57.0 815.0,57.0 815.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M815.0,169.0 L823.0,157.0 807.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-7" stroke-width="2px" d="M950,167.0 C950,112.0 1030.0,112.0 1030.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950,169.0 L942,157.0 958,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-8" stroke-width="2px" d="M180,167.0 C180,2.0 1040.0,2.0 1040.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1040.0,169.0 L1048.0,157.0 1032.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-948-0-9" stroke-width="2px" d="M1060,167.0 C1060,112.0 1140.0,112.0 1140.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-948-0-9" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1140.0,169.0 L1148.0,

# %%
for ent in doc.ents[:10]:
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# that day - DATE - Absolute or relative dates or periods
#
#  - GPE - Countries, cities, states
#
#  - GPE - Countries, cities, states
# Reed - PERSON - People, including fictional
#
#  - GPE - Countries, cities, states
# winter - DATE - Absolute or relative dates or periods
#
#  - GPE - Countries, cities, states
#
#  - GPE - Countries, cities, states
#
#  - GPE - Countries, cities, states
# Bessie - PERSON - People, including fictional

# %%
len([sent for sent in doc.sents])
# Out:
# 367

# %%
list_of_sents = [nlp(sent.text) for sent in doc.sents]
list_of_ners = [doc for doc in list_of_sents if doc.ents]
len(list_of_ners)
# Out:
# 264

# %%
displacy.render(list_of_sents[2], style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">There was no possibility of taking a walk
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     that day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .  </div>

# %%
displacy.render(list_of_sents[3], style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">We had been
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# wandering, indeed, in the leafless shrubbery an hour in the morning; but
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# since dinner (Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , when there was no company, dined early) the cold
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     winter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  wind had brought with it clouds so sombre, and a rain so
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# penetrating, that further out-door exercise was now out of the question.
#
# </div>
